# %% [markdown]
# ## 1) API Example

# %%
import datetime
import simplejson
import urllib

orig_coord = '37.7909,-122.3925'
dest_coord = '37.7765,-122.4506'
output_file_name = 'output.txt'

# https://developers.google.com/maps/documentation/javascript/get-api-key
apikey = 'AIzaSyB9ohXdz-pm_rH5JjgyT0w_t6HaKXQTUrU'
url = "https://maps.googleapis.com/maps/api/distancematrix/json?key={0}&origins={1}&destinations={2}&mode=driving&departure_time=now&language=en-EN&sensor=false".format(
    str(apikey), str(orig_coord), str(dest_coord))
result = simplejson.load(urllib.request.urlopen(url))
#driving_time = result['rows'][0]['elements'][0]['duration_in_traffic']['text']

print(result)
# Out:
# {'destination_addresses': ['2130 Fulton St, San Francisco, CA 94117, USA'], 'origin_addresses': ['101 Howard St, San Francisco, CA 94105, USA'], 'rows': [{'elements': [{'distance': {'text': '6.9 km', 'value': 6875}, 'duration': {'text': '22 mins', 'value': 1310}, 'duration_in_traffic': {'text': '16 mins', 'value': 987}, 'status': 'OK'}]}], 'status': 'OK'}

# %% [markdown]
# ## 2) wget Example

# %%
import wget
import xlrd # Extract data from Excel spreadsheets 

# Change in Food Price Index Forecast
url = "https://www.ers.usda.gov/webdocs/DataFiles/50673/CPIforecast.xlsx?v=7651"
filename = wget.download(url)
xl_workbook = xlrd.open_workbook(filename)
xl_sheet = xl_workbook.sheet_by_index(0)
num_cols = xl_sheet.ncols  
for row_idx in range(0, xl_sheet.nrows): # Iterate through rows
    for col_idx in range(0, num_cols):  # Iterate through columns
        cell_obj = xl_sheet.cell(row_idx, col_idx)  # Retrieve the cell value.
        print(cell_obj)
# Out:
# text:'Changes in Consumer Food Price Indexes, 2017 through 2020'
# empty:''
# empty:''
# empty:''
# empty:''
# empty:''
# empty:''
# empty:''
# empty:''
# text:'Consumer Price Index Item'
# text:'Relative importance1'
# text:'Month-to-month Dec. 2019 to Jan. 2020'
# text:'Year-over-year Jan. 2019 to Jan. 2020'
# text:'Annual 2017'
# text:'Annual 2018'
# text:'Annual 2019'
# text:'20-year historical average'
# text:'Forecast range2 2020'
# empty:''
# text:'Percent'
# text:'Percent change'
# empty:''
# empty:''
# empty:''
# empty:''
# empty:''
# empty:''
# text:'All food'
# number:100.0
# number:0.5
# number:1.8
# number:0.9
# number:1.4
# number:1.9
# number:2.3
# text:'1.5 to 2.5'
# empty:''
# empty:''
# empty:''
# empty:''
# empty:''
# empty:''
# empty:''
# empty:''
# empty:''
# text:'    Food away from home'
# number:45.2
# number:0.4
# number:3.1
# number:2.3
# number:2.6
# number:3.1
# number:2.8
# text:'2.0 to 3.0'
# empty:''
# empty:''
# empty:''
# empty:''
# empty:''
# ...

# %% [markdown]
# ## 3) Crawl - using selenium

# %%
from selenium import webdriver
url = "https://www.usfca.edu/arts-sciences/graduate-programs/data-science/our-students"
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")

# you can download driver from http://chromedriver.chromium.org/downloads
browser = webdriver.Chrome("./chromedriver_80_mac", options=chrome_options) 

browser.get(url)
print(browser.page_source)
# Out:
# <html class="js js no-touch boxshadow opacity cssgradients csstransforms video svg" lang="en" dir="ltr" style=""><!--<![endif]--><head>
#     <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# ...
